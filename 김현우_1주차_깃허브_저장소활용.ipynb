# %% [markdown]
# <a href="https://colab.research.google.com/github/dj202410113-sketch/eprhkaj/blob/main/%EA%B9%80%ED%98%84%EC%9A%B0_1%EC%A3%BC%EC%B0%A8_%EA%B9%83%ED%97%88%EB%B8%8C_%EC%A0%80%EC%9E%A5%EC%86%8C%ED%99%9C%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world!")
# Out:
# hello world!

# %%
i = int(input("원하는 단 입력"))
for j in range(1,10):
   print(f"{i}x{j}={i*j}")
# Out:
# 원하는 단 입력34
# 34x1=34
# 34x2=68
# 34x3=102
# 34x4=136
# 34x5=170
# 34x6=204
# 34x7=238
# 34x8=272
# 34x9=306
